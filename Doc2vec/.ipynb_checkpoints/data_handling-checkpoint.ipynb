# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra

# %%
template_df = pd.read_csv('./alimtalk_tempalte_parsed.csv', nrows=500000)
template_df.head(4)
# Out:
#    temp_id  sender_id  profile_id               content_word  \
# 0      NaN        NaN         NaN  계좌번호 가 집중모니터링 계좌로 등록되었습니다
# 1      NaN        NaN         NaN          종통결산액 한도 금액 잔액 금액
# 2      NaN        NaN         NaN      톡톡 구분값 고객 구분값 본인인증 완료
# 3      NaN        NaN         NaN           님 계좌 원 이자입금되었습니다
#
#              parsed_content name category_name temp_name target_yn group_yn
# 0   계좌 번호 가 집중 모니터링 계좌 등록되다  NaN           NaN       NaN       NaN      NaN
# 1        종통 결산액 한도 금액 잔액 금액  NaN           NaN       NaN       NaN      NaN
# 2  톡톡 구분 값 고객 구분 값 본인 인증 완료  NaN           NaN       NaN       NaN      NaN
# 3            님 계좌 원 이자 입금되다  NaN           NaN       NaN       NaN      NaN

# %%
# 템플릿 상태별 데이터 건수
#Group by
template_df.groupby(by='target_yn').size() #Series 형식으로 리턴
template_df.groupby(by='target_yn').size().reset_index(name='counts') # Dataframe 형태로 리턴
# Out:
#     target_yn  counts
# 0    비정상-검수반려    5198
# 1    비정상-검수안됨   12058
# 2      정상-발송됨  178406
# 3  정상-발송한적 없음  100103

# %%
#필터링
# Equal
template_df[template_df.target_yn == '정상-발송됨']

# in
template_df[template_df.target_yn.isin(['정상-발송됨', '비정상-검수안됨'])]

# null 필터링
template_df[~template_df.temp_id.isna()]

#template_df.target_yn in ['정상-발송됨', '비정상-검수안됨']
#template_df.target_yn.isin(['정상-발송됨', '비정상-검수안됨'])
# Out:
#          temp_id  sender_id   profile_id  \
# 31534      -25.0        2.0  193157236.0
# 31535        1.0        2.0  193157236.0
# 31536        7.0        3.0  177694379.0
# 31537        8.0        3.0  177694379.0
# 31538        9.0        3.0  177694379.0
# 31539       10.0        3.0  177694379.0
# 31540       11.0        3.0  177694379.0
# 31541       12.0        3.0  177694379.0
# 31542       13.0        3.0  177694379.0
# 31543       14.0        3.0  177694379.0
# 31544       15.0        3.0  177694379.0
# 31545       16.0        3.0  177694379.0
# 31546       17.0        3.0  177694379.0
# 31547       18.0        3.0  177694379.0
# 31548       19.0        3.0  177694379.0
# 31549       20.0        3.0  177694379.0
# 31550       21.0        3.0  177694379.0
# 31551       22.0        3.0  177694379.0
# 31552       23.0        3.0  177694379.0
# 31553       24.0        3.0  177694379.0
# 31554       25.0        3.0  177694379.0
# 31555       27.0        4.0  183215954.0
# 31556       31.0        3.0  177694379.0
# 31557       32.0        3.0  177694379.0
# 31558       33.0        3.0  177694379.0
# 31559       34.0        3.0  177694379.0
# 31560       35.0        3.0  177694379.0
# 31561       36.0        3.0  177694379.0
# 31562       37.0        3.0  177694379.0
# 31563       38.0        3.0  177694379.0
# ...          ...        ...          ...
# 359326  347868.0    18520.0  259579921.0
# 359327  347869.0    15535.0  252704750.0
# 359328  347870.0    15535.0  252704750.0
# 359329  347871.0    18520.0  259579921.0
# 359330  347872.0    15535.0  252704750.0
# 359331  347873.0    47762.0  285617962.0
# 359332  347874.0    15535.0  252704750.0
# 359333  347875.0    47762.0  285617962.0
# 359334  347876.0    31035.0  195355728.0
# 359335  347877.0    31035.0  195355728.0
# 359336  347878.0    44730.0  284284486.0
# 359337  347879.0    22390.0   72604153.0
# 359338  347880.0    31035.0  195355728.0
# 359339  347881.0    34559.0  277439462.0
# 359340  347882.0    34559.0  277439462.0
# 359341  347883.0    34559.0  277439462.0
# 359342  347884.0    34559.0  277439462.0
# 359343  347885.0    34559.0  277439462.0
# 359344  347886.0    47807.0  212894563.0
# 359345  347887.0    47807.0  212894563.0
# 359346  347888.0    34559.0  277439462.0
# 359347  347889.0    47807.0  212894563.0
# 359348  347890.0    31035.0  195355728.0
# 359349  347891.0    47807.0  212894563.0
# 359350  347892.0    47807.0  212894563.0
# 359351  347893.0    47807.0  212894563.0
# 359352  347894.0    44730.0  284284486.0
# 359353  347895.0    47807.0  212894563.0
# 359354  347896.0        NaN          NaN
# 359355  347897.0    22390.0   72604153.0
#
#                                              content_word  \
# 31534                                                "NA"
# 31535                        님이 보낸 등기 를 박덕민 회사동료 님께 배달 완료
# 31536   김은빈 고객님 우체국입니다 오늘 시부터 시 사이에 택배를 배달할 예정입니다 등기번호...
# 31537   신유리 고객님 우체국입니다 고객님이 님께 보내신 택배 등기번호 을 에 배달완료 하였...
# 31538   정혜민 고객님 우체국입니다 고객님이 부재중으로 등기우편물 등기번호 을 배달하지 못해...
# 31539   김현지 고객님 우체국입니다 고객님이 부재로 배달하지 못한 등기우편물 등기번호 을 년...
# 31540   윤영주 고객님 우체국입니다 폴샵 주 고객님이 발송한 택배 등기번호 을 경비원 경비원...
# 31541   주 다다글로벌 고객님 우체국입니다 고객님이 님께 보내신 택배 등기번호 가 에 반송되...
# 31542   박준영 고객님 우체국입니다 고객님이 님께 보내신 택배 등기번호 를 월 일 현재 님이...
# 31543   정보람 고객님 우체국입니다 오늘 등기우편물을 배달할 예정입니다 등기번호 운송장번호 ...
# 31544   참나무장작구이 고객님 우체국입니다 농협은행 주식회사 고객님이 보내신 등기우편물 등기...
# 31545   홍창익 고객님 우체국입니다 오늘 시 분부터 시 분 사이에 등기우편물을 배달할 예정입...
# 31546                               고객님의 는 배달완료 되었습니다 우체국
# 31547                          고객님의 가 반송되어 에 도착 하였습니다 우체국
# 31548                       고객님 의 국제 항공운송 준비가 완료되었습니다 우체국
# 31549                        고객님의 가 사유로 미배달 익일배달시도 예정 우체국
# 31550                      고객님께서 인터넷우체국을 통해 착불결제를 완료하였습니다
# 31551   고객님 오늘 배달예정인 등기우편물 에 대한 착불요금 원 을 인터넷우체국 에서 선결제...
# 31552   나채란 고객님 우체국입니다 고객님이 님께 보내신 우체국쇼핑 등기번호 을 에 배달완료...
# 31553   전통백일상 고객님 우체국입니다 전통백일상 고객님이 발송한 우체국쇼핑 등기번호 을 회...
# 31554   광명우체국장 고객님 우체국입니다 고객님이 님께 보내신 우체국쇼핑 등기번호 가 에 반...
# 31555                                             이거는 등록됨
# 31556   홍길동 고객님 우체국입니다 오늘 시부터 시 사이에 배달할 예정입니다 등기번호 운송장...
# 31557   홍길동 고객님 우체국입니다 오늘 시부터 시 사이에 배달할 예정입니다 등기번호 운송장...
# 359346  님 판매자 주문 상품 중 건 취소 승인하다 무통장 입금 취소 완료일 기준 익일 영업...          샵다나와
# 359347  후원자님 안녕하세요 사단 법인 지구촌 공생회 후원자님 보내다 주다 후원금 입금 확인...   사단법인 지구촌공생회
# 359348  발생 일시 매장 주님 시스템 장애 내용 알림이 발생되다 보다 자세하다 내용 공지 사...          티업비전
# 359349  후원자님 안녕하세요 사단 법인 지구촌 공생회 요청하다 계좌 번호 안내 돕다 드리다 ...   사단법인 지구촌공생회
# 359350  후원자님 안녕하세요 사단 법인 지구촌 공생회 약정 후원 만료 안내 차 연락 드리다 ...   사단법인 지구촌공생회
# 359351  후원자님 안녕하세요 사단 법인 지구촌 공생회 후원자님 후원하다 주다 케냐 아동 지원...   사단법인 지구촌공생회
# 359352  안녕하세요 하나 렌탈 고객 센터 이다 복합기 렌탈 제품 및 서비스 이용하다 느끼다 ...     하나렌탈 서울지사
# 359353  후원자님 안녕하세요 사단 법인 지구촌 공생회 이다 그 동안 후원자님 보내다 주다 소...   사단법인 지구촌공생회
# 359354  님 등록 번호 입원 예정 안내 입원 예정일 월 일 오전 오후 시 분 내원하다 입원하...           NaN
# 359355  롯데하이마트 서비스 센터 고객님 안녕하다 정성 다하다 롯데하이마트 고객님 구매하다 ...          하이마트
#
#        category_name               temp_name target_yn group_yn
# 31534             기타                 자유문자테스트  비정상-검수안됨        n
# 31535             기타                     테스트  비정상-검수안됨        n
# 31536          공공/행정              택배 배달 예정 1    정상-발송됨        n
# 31537          공공/행정              택배 배달 완료 1    정상-발송됨        n
# 31538          공공/행정               등기 우체국 보관    정상-발송됨        n
# 31539          공공/행정             등기 재배달 안내 1    정상-발송됨        n
# 31540          공공/행정              택배 배달 완료 2    정상-발송됨        n
# 31541          공공/행정              택배 반송 안내 1    정상-발송됨        n
# 31542          공공/행정                 택배 부재 1    정상-발송됨        n
# 31543          공공/행정              등기 배달 예정 1    정상-발송됨        n
# 31544          공공/행정              등기 배달 완료 1    정상-발송됨        n
# 31545          공공/행정              등기 배달 예정 2    정상-발송됨        n
# 31546          공공/행정             EMS 배달 완료 1    정상-발송됨        n
# 31547          공공/행정               EMS  반송 1    정상-발송됨        n
# 31548          공공/행정      EMS  국제항공운송준비 완료 1    정상-발송됨        n
# 31549          공공/행정               EMS 미배달 1    정상-발송됨        n
# 31550          공공/행정              착불 결제 완료 1    정상-발송됨        n
# 31551          공공/행정            착불 요금 선결제 안내    정상-발송됨        n
# 31552          공공/행정          우체국 쇼핑 배달 완료 1    정상-발송됨        n
# 31553          공공/행정          우체국 쇼핑 배달 완료 2    정상-발송됨        n
# 31554          공공/행정             우체국 쇼핑 반송 1    정상-발송됨        n
# 31555             기타                  fdfsdf       NaN        n
# 31556          공공/행정             국내등기소포-배달준비    정상-발송됨        n
# 31557          공공/행정            국내등기소포-배달준비2    정상-발송됨        n
# 31558          공공/행정         국내등기소포-배달(02-1)    정상-발송됨        n
# 31559          공공/행정         국내등기소포-보관(02-2)    정상-발송됨        n
# 31560          공공/행정      국내등기소포-재배달(02-2RD)    정상-발송됨        n
# 31561          공공/행정       국내등기소포-대리배달(02-3)    정상-발송됨        n
# 31562          공공/행정         국내등기소포-반송(02-4)    정상-발송됨        n
# 31563          공공/행정        국내등기소포-미배달(02-7)    정상-발송됨        n
# ...              ...                     ...       ...      ...
# 359326            의류                  현장수령안내       NaN        n
# 359327      정보통신/ SW      [EP]납기안내(3개월) TEST       NaN        n
# 359328      정보통신/ SW   [EP]납기안내(3개월) _ TEST1       NaN        n
# 359329            의류                 제작소주문안내       NaN        n
# 359330      정보통신/ SW   [EP]납기안내(3개월) _ TEST2       NaN        n
# 359331           유아동                    품절안내       NaN        n
# 359332      정보통신/ SW   [EP]납기안내(3개월) _ TEST3       NaN        n
# 359333           유아동                   품절안내_       NaN        n
# 359334           스포츠        제4회모두의명랑운동회_티업비전       NaN        n
# 359335           스포츠        제4회모두의명랑운동회티업비전2       NaN        n
# 359336        서비스 일반               5700 사용후기       NaN        n
# 359337         쇼핑 일반  고객서비스_소모품교체주기 안내(전기밥솥)       NaN        n
# 359338           스포츠         제4회모두의명랑운동회_지스윙       NaN        n
# 359339         쇼핑 일반         현금 주문 완료_180823       NaN        n
# 359340         쇼핑 일반         현금 결제 완료_180823       NaN        n
# 359341         쇼핑 일반         카드 주문 완료_180823       NaN        n
# 359342         쇼핑 일반         부분 판매 거절_180823       NaN        n
# 359343         쇼핑 일반       배송방법변경(거절)_180823       NaN        n
# 359344           비영리            후원가입신청 확인 안내       NaN        n
# 359345           비영리           후원금 미출금 안내 문자       NaN        n
# 359346         쇼핑 일반     판매자 부분 환불 승인_180823       NaN        n
# 359347           비영리         일시 후원금 입금 확인 안내       NaN        n
# 359348           스포츠                 시스템장애안내       NaN        n
# 359349           비영리       후원자가 후원계좌를 요청한 경우       NaN        n
# 359350           비영리  후원자에게 전화연락 후 부재 시 안내문자       NaN        n
# 359351           비영리        후원자 개별 보고서 발송 안내       NaN        n
# 359352        서비스 일반              2004설 치 후기       NaN        n
# 359353           비영리              후원 해지 시 안내       NaN        n
# 359354           NaN             등록번호입원예정안내문       NaN        y
# 359355         쇼핑 일반  고객서비스_소모품교체주기 안내(압력밥솥)       NaN        n
#
# [327822 rows x 10 columns]

# %%
#컬럼(변수) 선택
template_df[['temp_id','parsed_content','group_yn','target_yn']]

#컬럼 선택과 필터링 동시에
sample_df = template_df[['sender_id','temp_id','parsed_content','group_yn','target_yn']][template_df.target_yn == '정상-발송됨']

#Sorting
print(sample_df.head(5))
sample_df.sort_values(by='temp_id')#오름차순이 기본
sample_df.sort_values(by='temp_id', ascending=False)
sample_df.sort_values(by=['sender_id','temp_id'], ascending=False)
print(sample_df.head(5))
sample_df.sort_values(by=['sender_id','temp_id'], ascending=False, inplace=True) #Sorting 후 데이터 재저장
print(sample_df.head(5))
# Out:
#        sender_id  temp_id                                     parsed_content  \
# 31536        3.0      7.0  김은빈 고객님 우체국 오늘 시 시 사이 택배 배달하다 예정 등기 번호 운송장 번호 ...
# 31537        3.0      8.0  신유리 고객님 우체국 고객님 님 보내다 택배 등기 번호 을 에 배달 완료 하다 항상...
# 31538        3.0      9.0  정혜민 고객님 우체국 고객님 부재중 등기 우편물 등기 번호 을 배달하다 못하다 까다...
# 31539        3.0     10.0  김현지 고객님 우체국 고객님 부재 배달하다 못하다 등기 우편물 등기 번호 을 년 월...
# 31540        3.0     11.0  윤영주 고객님 우체국 폴샵 주 고객님 발송하다 택배 등기 번호 을 경비원 경비원 님...
#
#       group_yn target_yn
# 31536        n    정상-발송됨
# 31537        n    정상-발송됨
# 31538        n    정상-발송됨
# 31539        n    정상-발송됨
# 31540        n    정상-발송됨
#        sender_id  temp_id                                     parsed_content  \
# 31536        3.0      7.0  김은빈 고객님 우체국 오늘 시 시 사이 택배 배달하다 예정 등기 번호 운송장 번호 ...
# 31537        3.0      8.0  신유리 고객님 우체국 고객님 님 보내다 택배 등기 번호 을 에 배달 완료 하다 항상...
# 31538        3.0      9.0  정혜민 고객님 우체국 고객님 부재중 등기 우편물 등기 번호 을 배달하다 못하다 까다...
# 31539        3.0     10.0  김현지 고객님 우체국 고객님 부재 배달하다 못하다 등기 우편물 등기 번호 을 년 월...
# 31540        3.0     11.0  윤영주 고객님 우체국 폴샵 주 고객님 발송하다 택배 등기 번호 을 경비원 경비원 님...
#
#       group_yn target_yn
# 31536        n    정상-발송됨
# 31537        n    정상-발송됨
# 31538        n    정상-발송됨
# 31539        n    정상-발송됨
# 31540        n    정상-발송됨
#         sender_id   temp_id  \
# 358437    47762.0  346978.0
# 358264    47742.0  346805.0
# 358481    47708.0  347023.0
# 358479    47708.0  347021.0
# 358477    47708.0  347019.0
#
#                                            parsed_content group_yn target_yn
# 358437  품절 안내 님 에서 주문하다 상품 품절 확인 되다 상품명 처리 방법 에서 취소 접수...        n    정상-발송됨
# 358264  위드 유 쇼핑 출고 안내 상품 택배사 한진 택배 송장 번호 주문하 신상품 출고 완료...        n    정상-발송됨
# 358481                                     님 입금 계좌 노마진 마켓        n    정상-발송됨
# 358479                          님 입금 감사합니다 원 주문 번호 노마진 마켓        n    정상-발송됨
# 358477                             님 주문하다 주다 고맙다 원 노마진 마켓        n    정상-발송됨

# %%
#기초 통계량 보기
print(sample_df.describe())
print(sample_df.describe(include='all'))
# Out:
#            sender_id        temp_id
# count  167159.000000  178406.000000
# mean    10519.000903  145395.162074
# std     11258.707952   99021.626825
# min         2.000000       7.000000
# 25%      2430.000000   54197.250000
# 50%      5613.000000  137769.000000
# 75%     15345.000000  225811.750000
# max     47762.000000  347259.000000
#             sender_id        temp_id  \
# count   167159.000000  178406.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean     10519.000903  145395.162074
# std      11258.707952   99021.626825
# min          2.000000       7.000000
# 25%       2430.000000   54197.250000
# 50%       5613.000000  137769.000000
# 75%      15345.000000  225811.750000
# max      47762.000000  347259.000000
#
#                                            parsed_content group_yn target_yn
# count                                              178406   178406    178406
# unique                                             105430        2         1
# top     에서 사용하다 포인트 도용 방지 위하다 인증 번호 를 점원 보이다 주다 고객님 사용...        n    정상-발송됨
# freq                                                 4791   167330    178406
# mean                                                  NaN      NaN       NaN
# std                                                   NaN      NaN       NaN
# min                                                   NaN      NaN       NaN
# 25%                                                   NaN      NaN       NaN
# 50%                                                   NaN      NaN       NaN
# 75%                                                   NaN      NaN       NaN
# max                                                   NaN      NaN       NaN
